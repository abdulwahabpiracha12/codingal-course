# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Titanic Dataset.csv')

# %%
data.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Gender
# 0         A/5 21171   7.2500   NaN        S    male
# 1          PC 17599  71.2833   C85        C  female
# 2  STON/O2. 3101282   7.9250   NaN        S  female
# 3            113803  53.1000  C123        S  female
# 4            373450   8.0500   NaN        S    male

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          156
# Embarked         0
# Gender           0
# dtype: int64

# %%
"""**Null values present in Cabin -**"""

#### **Quartiles of Feature Age**

age_q1 = np.quantile(data['Age'], 0.25)
age_q2 = np.quantile(data['Age'], 0.50)
age_q3 = np.quantile(data['Age'], 0.75)

print("Age Quartiles -")
print("Q1 -", age_q1)
print("Q2 -", age_q2)
print("Q3 -", age_q3)
# Out:
# Age Quartiles -
# Q1 - 20.0
# Q2 - 27.76173076923077
# Q3 - 33.0

# %%
"""#### **Interquartile Range of Feature Age**"""

IQR_age = age_q3 - age_q1
print("Interquartile Range :", IQR_age)
# Out:
# Interquartile Range : 13.0

# %%
"""#### **Plot Histogram for feature Age**"""

plt.hist(data['Age'])
plt.ylabel("Count of Passengers")
plt.xlabel("Age")
# Out:
# Text(0.5, 0, 'Age')

# %%
"""#### **Quartiles for feature Fare**"""

fare_q1 = np.quantile(data['Fare'], 0.25)
fare_q2 = np.quantile(data['Fare'], 0.50)
fare_q3 = np.quantile(data['Fare'], 0.75)

print("Fare Quartiles -")
print("Q1 -", fare_q1)
print("Q2 -", fare_q2)
print("Q3 -", fare_q3)
# Out:
# Fare Quartiles -
# Q1 - 8.05
# Q2 - 15.05
# Q3 - 30.3833

# %%
"""#### **Interquartile Range of Feature Fare**"""

IQR_fare = fare_q3 - fare_q1
print("Interquartile Range :", IQR_fare)
# Out:
# Interquartile Range : 22.333299999999998

# %%
"""#### **Plot histogram for feature Fare**"""

bins = np.arange(0,250,20)
plt.hist(data['Fare'], bins=np.arange(1,250,20))
plt.ylabel("Count of Passengers")
plt.xlabel("Fare")
plt.xticks(bins)
# Out:
# ([<matplotlib.axis.XTick at 0x11c0d5ff110>,
#   <matplotlib.axis.XTick at 0x11c0d5fe990>,
#   <matplotlib.axis.XTick at 0x11c0d65e990>,
#   <matplotlib.axis.XTick at 0x11c0d65f110>,
#   <matplotlib.axis.XTick at 0x11c0d65f890>,
#   <matplotlib.axis.XTick at 0x11c0d698050>,
#   <matplotlib.axis.XTick at 0x11c0d6987d0>,
#   <matplotlib.axis.XTick at 0x11c0d698f50>,
#   <matplotlib.axis.XTick at 0x11c0d6996d0>,
#   <matplotlib.axis.XTick at 0x11c0d699e50>,
#   <matplotlib.axis.XTick at 0x11c0d69a5d0>,
#   <matplotlib.axis.XTick at 0x11c0d69ad50>,
#   <matplotlib.axis.XTick at 0x11c0d69b4d0>],
#  [Text(0, 0, '0'),
#   Text(20, 0, '20'),
#   Text(40, 0, '40'),
#   Text(60, 0, '60'),
#   Text(80, 0, '80'),
#   Text(100, 0, '100'),
#   Text(120, 0, '120'),
#   Text(140, 0, '140'),
#   Text(160, 0, '160'),
#   Text(180, 0, '180'),
#   Text(200, 0, '200'),
#   Text(220, 0, '220'),
#   Text(240, 0, '240')])
