# %%
####**Import Libararies**

# Import Libararies
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# Import dataset
data = pd.read_csv("Weather Dataset.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Import dataset
# ----> 2 data = pd.read_csv("Weather Dataset.csv")
#
# NameError: name 'pd' is not defined

# %%
data.head(5)

# %%
data.info()
